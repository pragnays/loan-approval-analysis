# %%
import pandas as pd

df = pd.read_csv('../data/loan_approval_dataset.csv')
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (4269, 13)
# ['loan_id', ' no_of_dependents', ' education', ' self_employed', ' income_annum', ' loan_amount', ' loan_term', ' cibil_score', ' residential_assets_value', ' commercial_assets_value', ' luxury_assets_value', ' bank_asset_value', ' loan_status']
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# ...

# %%
df.columns = df.columns.str.strip()
print(df.columns.tolist())
# Out:
# ['loan_id', 'no_of_dependents', 'education', 'self_employed', 'income_annum', 'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value', 'loan_status']

# %%
df['loan_status'] = df['loan_status'].str.strip()
print(df['loan_status'].value_counts())
print(df['loan_status'].value_counts(normalize=True) * 100)
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64
# loan_status
# Approved    62.215976
# Rejected    37.784024
# Name: proportion, dtype: float64

# %%
df['cibil_bucket'] = pd.cut(df['cibil_score'], bins=[0, 500, 650, 750, 900], labels=['Poor (<500)', 'Fair (500-650)', 'Good (650-750)', 'Excellent (750+)'])

approval_by_cibil = df.groupby('cibil_bucket')['loan_status'].value_counts(normalize=True).unstack() * 100
print(approval_by_cibil)
# Out:
# loan_status        Approved   Rejected
# cibil_bucket
# Poor (<500)       10.668563  89.331437
# Fair (500-650)    67.693744  32.306256
# Good (650-750)    99.323410   0.676590
# Excellent (750+)  99.430199   0.569801
# C:\Users\user\AppData\Local\Temp\ipykernel_34624\1682381959.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   approval_by_cibil = df.groupby('cibil_bucket')['loan_status'].value_counts(normalize=True).unstack() * 100

# %%
approval_by_education = df.groupby('education')['loan_status'].value_counts(normalize=True).unstack() * 100
print(approval_by_education)

approval_by_employment = df.groupby('self_employed')['loan_status'].value_counts(normalize=True).unstack() * 100
print(approval_by_employment)
# Out:
# loan_status    Approved   Rejected
# education
# Graduate      62.453358  37.546642
# Not Graduate  61.976471  38.023529
# loan_status     Approved   Rejected
# self_employed
# No             62.199151  37.800849
# Yes            62.232558  37.767442

# %%
approval_by_dependents = df.groupby('no_of_dependents')['loan_status'].value_counts(normalize=True).unstack() * 100
print(approval_by_dependents)
# Out:
# loan_status        Approved   Rejected
# no_of_dependents
# 0                 64.185393  35.814607
# 1                 61.692970  38.307030
# 2                 62.288136  37.711864
# 3                 62.861073  37.138927
# 4                 61.835106  38.164894
# 5                 60.326895  39.673105

# %%
approval_by_status = df.groupby('loan_status')[['income_annum', 'loan_amount', 'cibil_score']].mean()
print(approval_by_status)
# Out:
#              income_annum   loan_amount  cibil_score
# loan_status
# Approved     5.025904e+06  1.524725e+07   703.461973
# Rejected     5.113825e+06  1.494606e+07   429.468072

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='loan_status', y='cibil_score')
plt.title('CIBIL Score Distribution: Approved vs Rejected')
plt.savefig('../reports/chart1_cibil_by_status.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

sns.boxplot(data=df, x='loan_status', y='income_annum', ax=axes[0])
axes[0].set_title('Annual Income: Approved vs Rejected')

sns.boxplot(data=df, x='loan_status', y='loan_amount', ax=axes[1])
axes[1].set_title('Loan Amount: Approved vs Rejected')

plt.tight_layout()
plt.savefig('../reports/chart2_income_loanamount_by_status.png', dpi=150, bbox_inches='tight')
plt.show()
